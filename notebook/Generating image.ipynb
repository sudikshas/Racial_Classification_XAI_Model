# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import plotly
# Out:
# ModuleNotFoundErrorTraceback (most recent call last)
# <ipython-input-25-0011b34b2d38> in <module>
#       3 import numpy as np
#       4 import json
# ----> 5 import plotly
#
# ModuleNotFoundError: No module named 'plotly'

# %%
with open("./config/parameters.json") as f:
    data = json.load(f)
f.close()

info = data["load_data"]

# %%
train_path = info["train_label_path"]
df = pd.read_csv(train_path)
d1 = df.groupby("race").size()

# %%
# Out:
# array([14.1, 14.2, 14.2, 15.4, 10.6, 12.4, 19.1])

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = d1.index.values
sizes = np.around(d1.values / d1.values.sum() * 100, 1)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
