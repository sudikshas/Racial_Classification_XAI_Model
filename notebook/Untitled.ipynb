# %%
import numpy as np
import sys
sys.path.append("./src")
from util import *

# %%
a = np.array([1,2,3,4]).reshape(2,2)
b = np.array([3,4,5,6]).reshape(2,2)

# %%
np.min(np.concatenate([a,b]))
sample = "/teams/DSC180A_FA20_A00/a01explainableai/a01capstonegroup03/fairface_pad025/val/1063.jpg"
im = Image.open(sample)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F0C8AE2EEE0>

# %%
pic = integrated_grad_PIL_v2(im, "race", "white", True)
# Out:
# Evaluated output channel (0-based index): All
# Building gradient functions
# Progress: 100.0%
# Done.
# Evaluated output channel (0-based index): All
# Building gradient functions
# Progress: 100.0%
# Done.
# array route
# Explaning the 6th output.
# sample shape (224, 224, 3)
# input length: 2
# input type: <class 'list'>
# input shape: (50, 224, 224, 3)
# array route
# Explaning the 6th output.
# sample shape (224, 224, 3)
# input length: 2
# input type: <class 'list'>
# input shape: (50, 224, 224, 3)
